# %%
print("Application started...")
print("Loading customer data...")
print("Customer data loaded...")
print("Some records are missing")
# Out:
# Application started...
# Loading customer data...
# Customer data loaded...
# Some records are missing

# %%
import logging

logging.basicConfig(level = logging.INFO)

logging.info("Application started...")
logging.info("Loading customer data...")
logging.info("Customer data loaded...")
logging.warning("Some records are missing")
# Out:
# INFO:root:Application started...
# INFO:root:Loading customer data...
# INFO:root:Customer data loaded...
# WARNING:root:Some records are missing

# %%
import logging

logging.basicConfig(level = logging.INFO)

logging.debug("This is debugging info...")
logging.info("Appliucation started...")
logging.warning("date range is unexpecxted")
logging.error("Failed to process the order")
logging.critical("Databse is completely unavailble")
# Out:
# INFO:root:Appliucation started...
# WARNING:root:date range is unexpecxted
# ERROR:root:Failed to process the order
# CRITICAL:root:Databse is completely unavailble

# %%
order_id = "ORD-4567"
city = "Banglore"
amount = 2500

# %%
import logging

logging.basicConfig(
    level = logging.INFO
)

logging.info(f"Processig order {order_id}")
logging.info(f"Order City {city}")
logging.info(f"order amount is {amount}")
# Out:
# INFO:root:Processig order ORD-4567
# INFO:root:Order City Banglore
# INFO:root:order amount is 2500

# %%
import logging

logging.basicConfig(
    level = logging.INFO,
    format = "%(asctime)s | %(levelname)s | %(name)s | %(message)s"
)

logging.info(f"Processig order {order_id}")
logging.info(f"Order City {city}")
logging.info(f"order amount is {amount}")
# Out:
# 2026-09-06 13:48:08,661 | INFO | root | Processig order ORD-4567
# 2026-09-06 13:48:08,663 | INFO | root | Order City Banglore
# 2026-09-06 13:48:08,664 | INFO | root | order amount is 2500

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 logging.info()
#
# TypeError: info() missing 1 required positional argument: 'msg'

# %%
import logging

logging.basicConfig(
    level = logging.INFO,
    format = "%(asctime)s | %(levelname)s | %(name)s | %(message)s"
)


def load_orders():
    logging.info("starting the order loading...")

    orders = ["ORD-001","ORD-002","ORD-003"]
    logging.info(f"successfully loaded {len(orders)}")
    return orders

# %%
load_orders()
# Out:
# 2026-09-06 13:51:57,888 | INFO | root | starting the order loading...
# 2026-09-06 13:51:57,889 | INFO | root | successfully loaded 3
# ['ORD-001', 'ORD-002', 'ORD-003']

# %%
import logging

# logging.basicConfig(
#     level = logging.INFO,
#     format = "%(asctime)s | %(levelname)s | %(name)s | %(message)s"
# )

logger = logging.getLogger(__name__)


def load_orders():
    logging.info("starting the order loading...")

    orders = ["ORD-001","ORD-002","ORD-003"]
    logging.info(f"successfully loaded {len(orders)}")
    return orders

# %%
load_orders()
# Out:
# ['ORD-001', 'ORD-002', 'ORD-003']
