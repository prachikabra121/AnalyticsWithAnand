# %%
print("Hello World")
print("bye")
print("welcome back")
# Out:
# Hello World
# bye
# welcome back

# %%
# !python --version
# Out:
# Python 3.12.13

# %%
a=12

# %%
type(a)
# Out:
# int

# %%
num1 = 8

# %%
num2 = 9

# %%
sum = num1 + num2

# %%
8+9
# Out:
# 17

# %%
sum
# Out:
# 17

# %%
sum - 78
# Out:
# -61

# %%
n = 9

# %%
firstName='prachi'

# %%
FirstName='prachi'

# %%
First_Name = 'prachi'

# %%
9firstname = 90
# Out:
#   File "/tmp/ipykernel_2439/702426359.py", line 1
#     9firstname = 90
#     ^
# SyntaxError: invalid decimal literal

# %%
_firstname = 'prachi'

# %%
@fitrstname = 'prachi'
# Out:
#   File "/tmp/ipykernel_2439/4073170000.py", line 1
#     @fitrstname = 'prachi'
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
fitrstname% = 'prachi'
# Out:
#   File "/tmp/ipykernel_2439/1244471534.py", line 1
#     fitrstname% = 'prachi'
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# **keyword** - reserve words, 33 keywords in python

# %%
#keywords

import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
keyword.iskeyword('for')
# Out:
# True

# %%
keyword.iskeyword('hello')
# Out:
# False

# %%
num1 = 14

# %%
type(num1)
# Out:
# int

# %%
num2 = 1343.7

# %%
type(num2)
# Out:
# float

# %%
num3 = 3+7j

# %%
type(num3)
# Out:
# complex

# %%
flag = True

# %%
type(flag)
# Out:
# bool

# %%
l = [1,13.5,4+5j, 'prachi',{1,2,3,3,4},True]

# %%
l[0] = 98

# %%
l
# Out:
# [98, 13.5, (4+5j), 'prachi', {1, 2, 3, 4}, True]

# %%
type(l)
# Out:
# list

# %%
type(l[3])
# Out:
# str

# %%
s = 'Trisha Jha'

# %%
s[7:]
# Out:
# 'Jha'

# %%
s[-6]
# Out:
# 'h'

# %%
type(s)
# Out:
# str

# %%
d = {'Name':'Tanu','City':'Pune','Age':24}

# %%
type(d)
# Out:
# dict

# %%
d
# Out:
# {'Name': 'Tanu', 'City': 'Pune', 'Age': 24}

# %%
d['City']
# Out:
# 'Pune'

# %%
t = (1,'Ginger',True,9+8j)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 1

# %%
t[0]=89
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2549/1249214784.py in <cell line: 0>()
# ----> 1 t[0]=89
#
# TypeError: 'tuple' object does not support item assignment

# %%
s1 = {1,2,3,4,4,4,5,5,'prachi'}

# %%
s1
# Out:
# {1, 2, 3, 4, 5, 'prachi'}

# %% [markdown]
# Type Casting - type conversion -convert one data type into another
#
# why?

# %%
age = input("Enter your age :")
# Out:
# Enter your age :56

# %%
type(age)
# Out:
# str

# %%
age+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2549/1778316658.py in <cell line: 0>()
# ----> 1 age+5
#
# TypeError: can only concatenate str (not "int") to str

# %%
int(age)+5
# Out:
# 61

# %% [markdown]
# Types of type casting:
#
# 1)Implicit type casting -python automatically converts a smaller data type into a larger compatible type
#
# 2)Explicit type casting - programmer manually converts one data type to another

# %%
#implicit
a = 10
b=5.5

# %%
c = a+b

# %%
c
# Out:
# 15.5

# %%
type(c)
# Out:
# float

# %%
a = True
b=10

# %%
d=a+b

# %%
d
# Out:
# 11

# %%
type(d)
# Out:
# int

# %%
x=100
y=20.8

# %%
z=x/y

# %%
z
# Out:
# 4.8076923076923075

# %%
x='100'

# %%
type(x)
# Out:
# str

# %%
int(x) +5
# Out:
# 105

# %% [markdown]
# *   int()   - integer
# *   float() - float
# str()       - string
# bool()   - boolean
# list()  - lists

# %%
x=10.99

# %%
int(x)
# Out:
# 10

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
s = 'hello'

# %%
int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2549/2179186071.py in <cell line: 0>()
# ----> 1 int(s)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
s1 = '100'

# %%
int(s1)
# Out:
# 100

# %%
 n = 26

# %%
float(n)
# Out:
# 26.0

# %%
 s= '36'

# %%
float(s)
# Out:
# 36.0

# %%
s = 10.5
s1=10.5

# %%
s+s1
# Out:
# 21.0

# %%
bool(1)
# Out:
# True

# %%
bool(100)
# Out:
# True

# %%
bool(-100)
# Out:
# True

# %%
bool("")
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
bool([1,2,3])
# Out:
# True

# %%
bool([])
# Out:
# False

# %%
bool("Hello")
# Out:
# True

# %%
x = (10,89,56)

# %%
type(x)
# Out:
# tuple

# %%
y=list(x)

# %%
x
# Out:
# (10, 89, 56)

# %%
y
# Out:
# [10, 89, 56]

# %%
y[0]=90

# %%
y
# Out:
# [90, 89, 56]

# %%
z=tuple(y)

# %%
z
# Out:
# (90, 89, 56)

# %%
x ='Python'

# %%
y=list(x)

# %%
y
# Out:
# ['P', 'y', 't', 'h', 'o', 'n']

# %%
y[3]='g'

# %%
y
# Out:
# ['P', 'y', 't', 'g', 'o', 'n']

# %%
str(y)
# Out:
# "['P', 'y', 't', 'g', 'o', 'n']"

# %%
l=[1,2,2,3,4,5,7,8,9,2,3,4]

# %%
list(set(l))
# Out:
# [1, 2, 3, 4, 5, 7, 8, 9]

# %%
x=[("Name","Prachi"),("designation","DE")]

# %%
dict(x)
# Out:
# {'Name': 'Prachi', 'designation': 'DE'}

# %%
y = [1,2,3]

# %%
dict(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2549/1488190274.py in <cell line: 0>()
# ----> 1 dict(y)
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
a= 10
b= 3

# %%
a+b
# Out:
# 13

# %%
a-b
# Out:
# 7

# %%
a/b
# Out:
# 3.3333333333333335

# %%
a*b
# Out:
# 30

# %%
a//b
# Out:
# 3

# %%
a%b
# Out:
# 1

# %%
a**b
# Out:
# 1000

# %%
x=100

# %%
x
# Out:
# 100

# %%
x = x+5

# %%
x
# Out:
# 110

# %%
x+=5

# %%
x
# Out:
# 115

# %%
 x = x-5 # x -=5

# %%
a= 100
b= 200

# %%
a==b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a >b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
age = int(input("enter age"))
# Out:
# enter age23

# %%
age >= 18
# Out:
# True

# %%
10>5 or 20<10
# Out:
# True

# %%
True or False

# %%
age=25
sal = 60000

# %%
age > 18 and sal > 50000
# Out:
# True

# %%
age > 28 and sal > 50000
# Out:
# False

# %%
not age> 25
# Out:
# True

# %%
a = [1,2]

# %%
b= a

# %%
b
# Out:
# [1, 2]

# %%
 a is b
# Out:
# True

# %%
id(a)
# Out:
# 137476011888128

# %%
id(b)
# Out:
# 137476011888128

# %%
a = [1,2]
b=[1,2]

# %%
id(a)
# Out:
# 137476012300672

# %%
id(b)
# Out:
# 137476012025088

# %%
a is b
# Out:
# False

# %%
a ==b
# Out:
# True

# %%
a = [ 'apple','banana','cherry']

# %%
'apple' in a
# Out:
# True

# %%
'grape' in a
# Out:
# False
