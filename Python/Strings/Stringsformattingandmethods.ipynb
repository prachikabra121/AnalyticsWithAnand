# %%
s = " Prachi Kabra "

# %%
s1=s.strip()

# %%
s1
# Out:
# 'Prachi Kabra'

# %%
s
# Out:
# ' Prachi Kabra '

# %%
s.rstrip()
# Out:
# ' Prachi Kabra'

# %%
s.lstrip()
# Out:
# 'Prachi Kabra '

# %%
s2 = "Today,is,a,beautiful,day"

# %%
s2.split()
# Out:
# ['Today,is,a,beautiful,day']

# %%
s2.split('a')
# Out:
# ['Tod', 'y,is,', ',be', 'utiful,d', 'y']

# %%
s3=s2.split(',')

# %%
s3
# Out:
# ['Today', 'is', 'a', 'beautiful', 'day']

# %%
' '.join(s3)
# Out:
# 'Today is a beautiful day'

# %%
','.join(s3)
# Out:
# 'Today,is,a,beautiful,day'

# %%
s4 = ['today','is','saturday']

# %%
''.join(s4)
# Out:
# 'todayissaturday'

# %%
' '.join(s4)
# Out:
# 'today is saturday'

# %%
s5 = "Hello, World!"

# %%
s5=s5.replace('World','Python')

# %%
s5
# Out:
# 'Hello, Python!'

# %%
s6
# Out:
# 'Hello, Python!'

# %%
s5.find("Python")
# Out:
# 7

# %%
s5.find('World')
# Out:
# -1

# %%
s5.startswith('Hello')
# Out:
# True

# %%
s5.startswith('H')
# Out:
# True

# %%
s5.startswith('B')
# Out:
# False

# %%
s5.endswith('Python')
# Out:
# False

# %%
s5.endswith('!')
# Out:
# True

# %%
s6 = "Today is rainy day and its saturday"

# %%
s6.count('day')
# Out:
# 3

# %%
s6.count('a')
# Out:
# 6

# %%
name = "Prachi"
age = 27
sal = 26000

# %%
print("Hello: ",name,"Age: ",age)
# Out:
# Hello:  Prachi Age:  27

# %%
print("My name is %s and my age is %d and my salary is %d" %(name,age,sal))
# Out:
# My name is Prachi and my age is 27 and my salary is 26000

# %%
print("My name is %s and my age is %d and my salary is %d" %(name,sal,age))
# Out:
# My name is Prachi and my age is 26000 and my salary is 27

# %%
print("My name is {} and My age is  {} and my salary is {}".format(name,age,sal))
# Out:
# My name is Prachi and My age is  27 and my salary is 26000

# %%
print("My name is {} and My age is  {} and my salary is {}".format(age,name,sal))
# Out:
# My name is 27 and My age is  Prachi and my salary is 26000

# %%
print(f"My name is {name} and my age is {age} and my salary is {sal}")
# Out:
# My name is Prachi and my age is 27 and my salary is 26000

# %%
print(f"My name is {name} and my age is {age+1} and my salary is {sal+2600}")
# Out:
# My name is Prachi and my age is 28 and my salary is 28600

# %%
a=3.14159

# %%
print(f"Pi is approximately {a:.3f}")
# Out:
# Pi is approximately 3.142

# %% [markdown]
# Create a string that says, "John has 3 apples and 2 oranges.“

# %%
print("John has 3 apples and 2 oranges")
# Out:
# John has 3 apples and 2 oranges

# %% [markdown]
# Use an f-string to create a sentence that says: "The result of 8
# multiplied by 7 is 56.“

# %%
num1 = 8
num2 = 7
print(f"The of {num1} multiplied by {num2} is {num1*num2}")
# Out:
# The of 8 multiplied by 7 is 56

# %% [markdown]
# Given a = 5 and b = 3, use an f-string to create a sentence that says:
# "The sum of 5 and 3 is 8, and their product is 15."

# %%
a= 5
b=3
print(f"The Sum of {a} and {b} is {a+b}, and their product is {a*b}")
# Out:
# The Sum of 5 and 3 is 8, and their product is 15
