# %% [markdown]
# **1.Amazon receives customer orders throughout the day**

# %% [markdown]
# 1)In which data structure you will store the values of order

# %%
orders = [2500,1800,3500,1200,4800,2200,5200,1800,1200]

# %%
Avg(orders)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1612/1906201025.py in <cell line: 0>()
# ----> 1 Avg(orders)
#
# NameError: name 'Avg' is not defined

# %% [markdown]
# 2)Find the highest order value?

# %%
print(f"Highest Order Value:{max(orders)}")
# Out:
# Highest Order Value:5200

# %% [markdown]
# 3)Find lowest order value.

# %%
print(f"Lowest Order value: {min(orders)}")
# Out:
# Lowest Order value: 1200

# %% [markdown]
# 4)Calculate total sales.

# %%
print(f"Total sales: {sum(orders)}")
# Out:
# Total sales: 24200

# %% [markdown]
# 5)Calculate average order value.

# %%
print(f"Average Sales: {sum(orders)/len(orders)}")
# Out:
# Average Sales: 2688.8888888888887

# %% [markdown]
# 6)Remove duplicate order amounts.

# %%
set(orders)
# Out:
# {1200, 1800, 2200, 2500, 3500, 4800, 5200, 6500}

# %% [markdown]
# 7)Add a new order worth ₹6500.

# %%
orders.append(6500)

# %% [markdown]
# 8)Sort orders in ascending or descending order

# %%
orders.sort()

# %%
orders
# Out:
# [1200, 1200, 1800, 1800, 2200, 2500, 3500, 4800, 5200, 6500]

# %%
orders.sort(reverse=True)

# %%
orders
# Out:
# [6500, 5200, 4800, 3500, 2500, 2200, 1800, 1800, 1200, 1200]

# %% [markdown]
# **2.Employee Salary Processing**

# %%
salary = [45000,55000,60000,42000,90000,76000,51000]

# %% [markdown]
# 1)Total payroll

# %%
print(f"Total Payroll: {sum(salary)}")
# Out:
# Total Payroll: 419000

# %% [markdown]
# 2)Highest salary

# %%
print(f"Highest Salary: {max(salary)}")
# Out:
# Highest Salary: 90000

# %% [markdown]
# 3)Lowest salary

# %%
print(f"Lowest Salary: {min(salary)}")
# Out:
# Lowest Salary: 42000

# %% [markdown]
# **3.GPS Coordinates**

# %%
warehouse = (12.9716,77.5946)

# %%
print(f"Latitude: {warehouse[0]}")
print(f"Longitude: {warehouse[1]}")
# Out:
# Latitude: 12.9716
# Longitude: 77.5946

# %% [markdown]
# **4.Employee dataset**

# %%
employee = {"id":101,"name":"Sakshi","Department":"IT","Salary":50000}

# %% [markdown]
# 1)update salary

# %%
employee["Salary"] = 70000

# %%
employee
# Out:
# {'id': 101, 'name': 'Sakshi', 'Department': 'IT', 'Salary': 70000}

# %% [markdown]
# 2)Add location

# %%
employee["Location"] = "Banglore"

# %%
employee
# Out:
# {'id': 101,
#  'name': 'Sakshi',
#  'Department': 'IT',
#  'Salary': 70000,
#  'Location': 'Banglore'}

# %% [markdown]
# 3)Remove department

# %%
employee.pop("Department")
# Out:
# 'IT'

# %%
employee
# Out:
# {'id': 101, 'name': 'Sakshi', 'Salary': 70000, 'Location': 'Banglore'}

# %% [markdown]
# 4)Print all keys

# %%
employee.keys()
# Out:
# dict_keys(['id', 'name', 'Salary', 'Location'])

# %%
employee.values()
# Out:
# dict_values([101, 'Sakshi', 70000, 'Banglore'])

# %%
employee.items()
# Out:
# dict_items([('id', 101), ('name', 'Sakshi'), ('Salary', 70000), ('Location', 'Banglore')])

# %% [markdown]
# **5.Student marks**

# %%
marks = {"Amit":99,"Riya":78,"Ashish":87,"Neha":82,"Prachi":67}

# %% [markdown]
# 1)Find the topper

# %%
max(marks,key=marks.get)
# Out:
# 'Amit'

# %%
marks.get("Neha")
# Out:
# 82

# %%
max(marks)
# Out:
# 'Riya'

# %% [markdown]
# 2)Lowest scorer

# %%
min(marks,key=marks.get)
# Out:
# 'Prachi'

# %% [markdown]
# 3)total marks

# %%
sum(marks.values())
# Out:
# 413

# %% [markdown]
# 4)Average marks

# %%
sum(marks.values())/len(marks)
# Out:
# 82.6

# %% [markdown]
# **5. store unique customers**

# %%
customer = {"A101","A102","A103","A104"}

# %% [markdown]
# 1)count customers

# %%
len(customer)
# Out:
# 4

# %% [markdown]
# 2)Add A105

# %%
customer.add("A105")

# %%
customer
# Out:
# {'A101', 'A102', 'A103', 'A104', 'A105'}

# %%
customer.remove("104")

# %% [markdown]
# 3)check A110 is exist?

# %%
"A110" in customer
# Out:
# False

# %% [markdown]
# **6. Email Campaign analysis**

# %%
email = {"A101","A102","A103","A104"}

mobile = {"A103","A104","A105","A106"}

# %% [markdown]
# 1)Common customer

# %%
email&mobile
# Out:
# {'A103', 'A104'}

# %% [markdown]
# 2)total custmors

# %%
len(email | mobile)
# Out:
# 6

# %% [markdown]
# 3)only email users

# %%
email-mobile
# Out:
# {'A101', 'A102'}

# %% [markdown]
# 4)only mobile ussers

# %%
mobile-email
# Out:
# {'A105', 'A106'}

# %% [markdown]
# **8. Inventory Management**

# %%
inventory = {"Laptop":26,"Mouse":150,"Keyboard":80,"Monitor":45}

# %% [markdown]
# 1)Add Printer

# %%
inventory["priner"]=30

# %%
inventory
# Out:
# {'Laptop': 26, 'Mouse': 150, 'Keyboard': 80, 'Monitor': 45, 'priner': 30}

# %% [markdown]
# 2)Update Laptop stock

# %%
inventory["Laptop"]=78

# %%
inventory
# Out:
# {'Laptop': 78, 'Mouse': 150, 'Keyboard': 80, 'Monitor': 45, 'priner': 30}

# %%
inventory.pop("laptop")
# Out:
# 78

# %% [markdown]
# 3)Find Product with lowest stock

# %%
min(inventory , key= inventory.get)
# Out:
# 'priner'
