# %%
s1 = {1,2,1,2,1,3,4,True,False,0,'Prachi'}

# %%
s1
# Out:
# {1, 2, 3, 4, False, 'Prachi'}

# %%
4 in s1
# Out:
# True

# %%
5 in s1
# Out:
# False

# %%
s1.remove(4)

# %%
s1
# Out:
# {1, 2, 3, False, 'Prachi'}

# %%
s1.remove(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1759/4190982174.py in <cell line: 0>()
# ----> 1 s1.remove(5)
#
# KeyError: 5

# %%
s1.discard(5)

# %%
s1.discard(3)

# %%
s1
# Out:
# {1, 2, False, 'Prachi'}

# %%
s1.add(5)

# %%
s1
# Out:
# {1, 2, 5, False, 'Prachi'}

# %%
s2={2,3,4}
s3={4,5,6}

# %%
s2|s3
# Out:
# {2, 3, 4, 5, 6}

# %%
s2&s3
# Out:
# {4}

# %%
s2-s3
# Out:
# {2, 3}

# %%
s2^s3
# Out:
# {2, 3, 5, 6}

# %%
s1
# Out:
# {1, 2, 5, False, 'Prachi'}

# %%
s1.update([6,7,8])

# %%
s1
# Out:
# {1, 2, 5, 6, 7, 8, False, 'Prachi'}

# %%
s1.update([5,6])

# %%
s1
# Out:
# {1, 2, 5, 6, 7, 8, False, 'Prachi'}

# %%
s1.update([9])

# %%
s1
# Out:
# {1, 2, 5, 6, 7, 8, 9, False, 'Prachi'}

# %%
s1.add(10)

# %%
s1
# Out:
# {1, 10, 2, 5, 6, 7, 8, 9, False, 'Prachi'}

# %%
s1.pop()
# Out:
# 1

# %%
s1
# Out:
# {10, 2, 5, 6, 7, 8, 9, 'Prachi'}

# %%
s1.pop()
# Out:
# 5

# %%
s1
# Out:
# {10, 6, 7, 8, 9, 'Prachi'}

# %%
s1.clear()

# %%
s1
# Out:
# set()

# %%
d1={"name":'Prachi',"City":"Ahemdabad","Dsignation":"Data Engineer"}

# %%
d1
# Out:
# {'name': 'Prachi', 'City': 'Ahemdabad', 'Dsignation': 'Data Engineer'}

# %%
d2=dict(name='prachi',city='Ahemdabad',designation='data engineer')

# %%
d2
# Out:
# {'name': 'prachi', 'city': 'Ahemdabad', 'designation': 'data engineer'}

# %%
d1['name']
# Out:
# 'Prachi'

# %%
d1.get('name')
# Out:
# 'Prachi'

# %%
d1['City']
# Out:
# 'Ahemdabad'

# %%
d1.get('City')
# Out:
# 'Ahemdabad'

# %%
d1['company_Name'] = 'S&P GLOBAL'

# %%
d1
# Out:
# {'name': 'Prachi',
#  'City': 'Ahemdabad',
#  'Dsignation': 'Data Engineer',
#  'company_Name': 'S&P GLOBAL'}

# %%
d1['City'] ='Pune'

# %%
d1
# Out:
# {'name': 'Prachi',
#  'City': 'Pune',
#  'Dsignation': 'Data Engineer',
#  'company_Name': 'S&P GLOBAL'}

# %%
d1.pop('company_Name')
# Out:
# 'S&P GLOBAL'

# %%
d1
# Out:
# {'name': 'Prachi', 'City': 'Pune', 'Dsignation': 'Data Engineer'}

# %%
d1.popitem()
# Out:
# ('Dsignation', 'Data Engineer')

# %%
d1
# Out:
# {'name': 'Prachi', 'City': 'Pune'}

# %%
d1.pop('company_Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1759/2658517265.py in <cell line: 0>()
# ----> 1 d1.pop('company_Name')
#
# KeyError: 'company_Name'

# %%
del d1['City']

# %%
d1
# Out:
# {'name': 'Prachi'}

# %%
d1.clear()

# %%
d1
# Out:
# {}

# %%
d2
# Out:
# {'name': 'prachi', 'city': 'Ahemdabad', 'designation': 'data engineer'}

# %%
d2.keys()
# Out:
# dict_keys(['name', 'city', 'designation'])

# %%
d2.values()
# Out:
# dict_values(['prachi', 'Ahemdabad', 'data engineer'])

# %%
d2.items()
# Out:
# dict_items([('name', 'prachi'), ('city', 'Ahemdabad'), ('designation', 'data engineer')])

# %%
employee = {"id":101,'name':"Trisha","skills":["Python","sql"]}

# %%
emp_copy = employee.copy()

# %%
id(employee)
# Out:
# 132885282435200

# %%
id(emp_copy)
# Out:
# 132885282395520

# %%
id(employee['skills'])
# Out:
# 132885282438848

# %%
id(emp_copy['skills'])
# Out:
# 132885282438848

# %%
emp_copy
# Out:
# {'id': 101, 'name': 'Trisha', 'skills': ['Python', 'sql']}

# %%
emp_copy['skills'].append("snowflake")

# %%
emp_copy
# Out:
# {'id': 101, 'name': 'Trisha', 'skills': ['Python', 'sql', 'snowflake']}

# %%
employee
# Out:
# {'id': 101, 'name': 'Trisha', 'skills': ['Python', 'sql', 'snowflake']}

# %%
emp_copy['name']="Trisha Jha"

# %%
emp_copy
# Out:
# {'id': 101, 'name': 'Trisha Jha', 'skills': ['Python', 'sql', 'snowflake']}

# %%
employee
# Out:
# {'id': 101, 'name': 'Trisha', 'skills': ['Python', 'sql', 'snowflake']}

# %%
import copy
emp_deep_copy = copy.deepcopy(employee)

# %%
id(employee)
# Out:
# 132885282435200

# %%
id(emp_deep_copy)
# Out:
# 132885826881664

# %%
id(employee['skills'])
# Out:
# 132885282438848

# %%
id(emp_deep_copy['skills'])
# Out:
# 132885282214336

# %%
d3={"child1":{"name":"A","DOB":"24th July 2026",'PLACE OF BIRTH':"Pune"},
    "child2":{"name":"B","DOB":"25th July 2026",'PLACE OF BIRTH':"Mumbai"}}

# %%
d3
# Out:
# {'child1': {'name': 'A', 'DOB': '24th July 2026', 'PLACE OF BIRTH': 'Pune'},
#  'child2': {'name': 'B', 'DOB': '25th July 2026', 'PLACE OF BIRTH': 'Mumbai'}}

# %%
d3["child2"]['DOB']
# Out:
# '25th July 2026'
